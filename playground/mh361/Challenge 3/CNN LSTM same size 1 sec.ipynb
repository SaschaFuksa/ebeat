# %%
import librosa
import numpy as np
#import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from pydub import AudioSegment
from scipy import signal
from sklearn import preprocessing

# %%
pathAudio = '/home/stud/m/mh361/share/samples1sec/'
files = librosa.util.find_files(pathAudio, ext=['mp3'])

song_lounge_it = []
song_tuesday_night = []
song_kingtop = []
for file in files:
    if 'Maarten Schellekens - Lounge It' in file:
        song_lounge_it.append(file)
    if 'Maarten Schellekens - Tuesday Night Radio Edit' in file:
        song_tuesday_night.append(file)
    if 'Holizna' in file:
        song_kingtop.append(file)
song_lounge_it = sorted(song_lounge_it, key=lambda x: int(x.split('_')[-1].split('.')[0]))
song_tuesday_night = sorted(song_tuesday_night, key=lambda x: int(x.split('_')[-1].split('.')[0]))
song_kingtop = sorted(song_kingtop, key=lambda x: int(x.split('_')[-1].split('.')[0]))

# %%
'Maarten Schellekens - Tuesday Night Radio Edit_43'
long_sample = song_tuesday_night[42]

# %%
# Check large sample
from matplotlib import pyplot as plt


def normalize_sample(sample):
    array_of_samples = sample.get_array_of_samples()
    np_arr = np.array(array_of_samples)
    np_arr = np_arr.reshape(1, -1)
    return preprocessing.normalize(np_arr)

sample = AudioSegment.from_mp3(long_sample)
mono_samples = sample.split_to_mono()
normalized_sample = normalize_sample(mono_samples[0])[0]

print(len(normalized_sample))
plt.plot(normalized_sample)
plt.show()

resampled_sample = signal.resample(normalized_sample, 1000)

plt.plot(resampled_sample)
plt.show()
# Out:
# 44100

# %%
print(len(song_lounge_it))
print(len(song_tuesday_night))
print(len(song_kingtop))
# Out:
# 299
# 282
# 222

# %%
full_songs = []
full_songs.extend(song_lounge_it)
full_songs.extend(song_tuesday_night)
full_songs.extend(song_kingtop)
len(full_songs)
# Out:
# 803

# %%
# todo: Check smallest sample!!
samples = []
samples_sec_canal = []
for file_name in full_songs:
    sample = AudioSegment.from_mp3(file_name)
    mono_samples = sample.split_to_mono()
    normalized_sample = normalize_sample(mono_samples[0])[0]
    #resampled_sample = signal.resample(normalized_sample, 1000)
    samples.append(normalized_sample)
    normalized_sample_sec_canal = normalize_sample(mono_samples[1])[0]
    #resampled_sample_sec_canal = signal.resample(normalized_sample_sec_canal, 1000)
    samples_sec_canal.append(normalized_sample_sec_canal)

# %%
min(map(len, samples))
# Out:
# 5997

# %%
import itertools

plt.plot(list(itertools.chain.from_iterable(samples)))
plt.show()

# %%
len(samples)
# Out:
# 803

# %%
# todo: Check smallest sample!!
samples = []
samples_sec_canal = []
for file_name in full_songs:
    sample = AudioSegment.from_mp3(file_name)
    mono_samples = sample.split_to_mono()
    normalized_sample = normalize_sample(mono_samples[0])[0]
    resampled_sample = signal.resample(normalized_sample, int(len(normalized_sample)/50))
    samples.append(resampled_sample)
    normalized_sample_sec_canal = normalize_sample(mono_samples[1])[0]
    resampled_sample_sec_canal = signal.resample(normalized_sample_sec_canal, int(len(normalized_sample)/50))
    samples_sec_canal.append(resampled_sample_sec_canal)

# %%
edge_size = min(map(len, samples))

# %%
plt.plot(list(itertools.chain.from_iterable(samples)))
plt.show()

# %%
X_train = []
Y_train = []
for i in range(len(samples)-1):
    Y_train.append(True)
    first_half = list(samples[i][-edge_size:])
    last_half = list(samples[i + 1][:edge_size])
    X_train.append(first_half+last_half)
    if(i < len(samples)-2):
        Y_train.append(True)
        sec_last_half = list(samples[i + 2][:edge_size])
        X_train.append(first_half+sec_last_half)

# %%
min(map(len, X_train))
# Out:
# 238

# %%
len(X_train)
# Out:
# 1603

# %%
plt.plot(X_train[1])
plt.show()

# %%
from numpy import random

def get_strange_end_part(samples, current_index, max_len):
    x = random.randint(max_len-1)
    if (x != current_index+1) and (x != current_index+2):
        return list(samples[x][:edge_size])
    else:
        return get_strange_end_part(samples, current_index, max_len)


for i in range(len(samples)-1):
    first_half = list(samples[i][-edge_size:])
    last_half = get_strange_end_part(samples, i, len(samples))
    X_train.append(first_half+last_half)
    Y_train.append(False)
    sec_last_half = get_strange_end_part(samples, i, len(samples))
    X_train.append(first_half+sec_last_half)
    Y_train.append(False)

# %%
len(X_train)
# Out:
# 3207

# %%
min(map(len, X_train))
# Out:
# 238

# %%
X_train = np.array(X_train)
X_train = X_train.reshape(-1, 2*edge_size)
X_train.shape
# Out:
# (3207, 238)

# %%
Y_train = np.array(Y_train)
Y_train = Y_train.reshape(-1, 1)
Y_train.shape
# Out:
# (3207, 1)

# %%
from keras.layers import Conv1D, LSTM, Flatten, CuDNNLSTM
from tensorflow.keras.optimizers import SGD

model = Sequential()
model.add(Conv1D(filters=512, kernel_size=2, input_shape=(2*edge_size, 1))) # 2 # 3 / filters 512
model.add(CuDNNLSTM(512, return_sequences=True)) # 256 # 8 #512 #256
model.add(Dense(512))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy']) #1 'rmsprop' 2 'adam' 3 SGD(learning_rate=0.01)
model.summary()
# Out:
# 2022-06-24 11:36:25.329336: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-24 11:36:25.872402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9634 MB memory:  -> device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:05:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 237, 512)          1536
#
#  cu_dnnlstm (CuDNNLSTM)      (None, 237, 512)          2101248
#
#  dense (Dense)               (None, 237, 512)          262656
#
#  flatten (Flatten)           (None, 121344)            0
#
#  dense_1 (Dense)             (None, 1)                 121345
#
# =================================================================
# Total params: 2,486,785
# Trainable params: 2,486,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, epochs=100, batch_size=32) 
# batch size 8
#3s 21ms/step - loss: 0.6818 - accuracy: 0.5719
# 3s 21ms/step - loss: 0.7044 - accuracy: 0.5729
# 3s 21ms/step - loss: 0.6933 - accuracy: 0.4747
# 2s 17ms/step - loss: 0.6923 - accuracy: 0.5574
# 3s 29ms/step - loss: 0.6837 - accuracy: 0.5667
#121/121 [==============================] - 4s 30ms/step - loss: 0.6872 - accuracy: 0.5595 filters 512 , lstm 512

#batch size 64
# 2s 117ms/step - loss: 0.6428 - accuracy: 0.5957
#16/16 [==============================] - 2s 114ms/step - loss: 0.6905 - accuracy: 0.5522 -> kernel 4 lstm 512
# 16/16 [==============================] - 2s 115ms/step - loss: 0.6914 - accuracy: 0.5429 kernel 3 lstm 512
# 16/16 [==============================] - 2s 134ms/step - loss: 0.6446 - accuracy: 0.6070 kernel 2 lstm 512 filters 512
# Epoch 1000/1000
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5504 - accuracy: 0.6856

#batch size 32
#  1s 46ms/step - loss: 0.7023 - accuracy: 0.5553

#batch size 128
#1s 92ms/step - loss: 0.6887 - accuracy: 0.5346
# Out:
# Epoch 1/100
# 2022-06-24 11:36:28.048662: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 7605
# 2022-06-24 11:36:28.049928: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-24 11:36:28.050690: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-24 11:36:28.050716: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-06-24 11:36:28.051104: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-24 11:36:28.051162: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 101/101 [==============================] - 9s 56ms/step - loss: 0.8144 - accuracy: 0.4983
# Epoch 2/100
# 101/101 [==============================] - 3s 25ms/step - loss: 0.7184 - accuracy: 0.4920
# Epoch 3/100
# 101/101 [==============================] - 2s 24ms/step - loss: 0.7812 - accuracy: 0.5017
# Epoch 4/100
# 101/101 [==============================] - 3s 25ms/step - loss: 0.7163 - accuracy: 0.4827
# Epoch 5/100
# 101/101 [==============================] - 2s 25ms/step - loss: 0.7282 - accuracy: 0.4814
# Epoch 6/100
# 101/101 [==============================] - 2s 25ms/step - loss: 0.7317 - accuracy: 0.4852
# Epoch 7/100
# 101/101 [==============================] - 2s 25ms/step - loss: 0.7161 - accuracy: 0.4843
# Epoch 8/100
# 101/101 [==============================] - 2s 24ms/step - loss: 0.7211 - accuracy: 0.4892
# Epoch 9/100
# 101/101 [==============================] - 2s 25ms/step - loss: 0.7075 - accuracy: 0.4896
# Epoch 10/100
# 101/101 [==============================] - 2s 25ms/step - loss: 0.7080 - accuracy: 0.4992
# Epoch 11/100
# 101/101 [==============================] - 2s 25ms/step - loss: 0.7098 - accuracy: 0.5036
# Epoch 12/100
# 101/101 [==============================] - 3s 25ms/step - loss: 0.7009 - accuracy: 0.5170
# Epoch 13/100
# 101/101 [==============================] - 3s 25ms/step - loss: 0.7043 - accuracy: 0.5020
# Epoch 14/100
# 101/101 [==============================] - 3s 25ms/step - loss: 0.7138 - accuracy: 0.5142
# Epoch 15/100
# 101/101 [==============================] - 2s 25ms/step - loss: 0.7077 - accuracy: 0.4992
# Epoch 16/100
# 101/101 [==============================] - 3s 25ms/step - loss: 0.7027 - accuracy: 0.5020
# Epoch 17/100
# 101/101 [==============================] - 3s 26ms/step - loss: 0.7036 - accuracy: 0.5051
# Epoch 18/100
# 101/101 [==============================] - 3s 26ms/step - loss: 0.6999 - accuracy: 0.4970
# Epoch 19/100
# 101/101 [==============================] - 3s 26ms/step - loss: 0.7061 - accuracy: 0.4977
# Epoch 20/100
# 101/101 [==============================] - 3s 26ms/step - loss: 0.7037 - accuracy: 0.5008
# Epoch 21/100
# 101/101 [==============================] - 3s 26ms/step - loss: 0.7295 - accuracy: 0.4917
# Epoch 22/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6985 - accuracy: 0.4949
# Epoch 23/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7016 - accuracy: 0.5005
# Epoch 24/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6993 - accuracy: 0.4905
# Epoch 25/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7102 - accuracy: 0.5101
# Epoch 26/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7013 - accuracy: 0.5042
# Epoch 27/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7076 - accuracy: 0.4908
# Epoch 28/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7006 - accuracy: 0.5192
# Epoch 29/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6979 - accuracy: 0.5014
# Epoch 30/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6984 - accuracy: 0.5073
# Epoch 31/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6993 - accuracy: 0.4992
# Epoch 32/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7021 - accuracy: 0.5014
# Epoch 33/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6989 - accuracy: 0.5030
# Epoch 34/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6975 - accuracy: 0.5020
# Epoch 35/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7075 - accuracy: 0.5089
# Epoch 36/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6977 - accuracy: 0.5039
# Epoch 37/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6981 - accuracy: 0.4967
# Epoch 38/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7007 - accuracy: 0.4973
# Epoch 39/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6983 - accuracy: 0.5002
# Epoch 40/100
# 101/101 [==============================] - 3s 26ms/step - loss: 0.7020 - accuracy: 0.5045
# Epoch 41/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7004 - accuracy: 0.5114
# Epoch 42/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7008 - accuracy: 0.5014
# Epoch 43/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6990 - accuracy: 0.5055
# Epoch 44/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6986 - accuracy: 0.5055
# Epoch 45/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6972 - accuracy: 0.5129
# Epoch 46/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7030 - accuracy: 0.5148
# Epoch 47/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.7008 - accuracy: 0.5111
# Epoch 48/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6979 - accuracy: 0.5042
# Epoch 49/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6989 - accuracy: 0.5214
# Epoch 50/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6966 - accuracy: 0.5157
# Epoch 51/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6961 - accuracy: 0.5229
# Epoch 52/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6977 - accuracy: 0.5226
# Epoch 53/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6969 - accuracy: 0.5167
# Epoch 54/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6951 - accuracy: 0.5123
# Epoch 55/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6951 - accuracy: 0.5282
# Epoch 56/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6966 - accuracy: 0.5111
# Epoch 57/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6968 - accuracy: 0.5235
# Epoch 58/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6956 - accuracy: 0.5182
# Epoch 59/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6959 - accuracy: 0.5179
# Epoch 60/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6936 - accuracy: 0.5263
# Epoch 61/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6931 - accuracy: 0.5273
# Epoch 62/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6944 - accuracy: 0.5139
# Epoch 63/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6936 - accuracy: 0.5267
# Epoch 64/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6938 - accuracy: 0.5179
# Epoch 65/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6940 - accuracy: 0.5173
# Epoch 66/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6951 - accuracy: 0.5313
# Epoch 67/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6947 - accuracy: 0.5198
# Epoch 68/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6942 - accuracy: 0.5279
# Epoch 69/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6948 - accuracy: 0.5270
# Epoch 70/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6933 - accuracy: 0.5223
# Epoch 71/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6962 - accuracy: 0.5204
# Epoch 72/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6951 - accuracy: 0.5276
# Epoch 73/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6980 - accuracy: 0.5204
# Epoch 74/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6948 - accuracy: 0.5363
# Epoch 75/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6932 - accuracy: 0.5295
# Epoch 76/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6922 - accuracy: 0.5267
# Epoch 77/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6928 - accuracy: 0.5123
# Epoch 78/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6940 - accuracy: 0.5176
# Epoch 79/100
# 101/101 [==============================] - 3s 26ms/step - loss: 0.6925 - accuracy: 0.5267
# Epoch 80/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6953 - accuracy: 0.5198
# Epoch 81/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6942 - accuracy: 0.5254
# Epoch 82/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6932 - accuracy: 0.5201
# Epoch 83/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6931 - accuracy: 0.5323
# Epoch 84/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6933 - accuracy: 0.5210
# Epoch 85/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6929 - accuracy: 0.5248
# Epoch 86/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6939 - accuracy: 0.5232
# Epoch 87/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6927 - accuracy: 0.5292
# Epoch 88/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6936 - accuracy: 0.5316
# Epoch 89/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6994 - accuracy: 0.5432
# Epoch 90/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6926 - accuracy: 0.5267
# Epoch 91/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6920 - accuracy: 0.5320
# Epoch 92/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6931 - accuracy: 0.5360
# Epoch 93/100
# 101/101 [==============================] - 3s 26ms/step - loss: 0.6935 - accuracy: 0.5304
# Epoch 94/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6929 - accuracy: 0.5273
# Epoch 95/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6930 - accuracy: 0.5254
# Epoch 96/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6922 - accuracy: 0.5248
# Epoch 97/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6928 - accuracy: 0.5426
# Epoch 98/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6929 - accuracy: 0.5285
# Epoch 99/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6942 - accuracy: 0.5248
# Epoch 100/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.6911 - accuracy: 0.5363

# %%
example_x_train = X_train[-2]
example_x_train = example_x_train.reshape(1, 2*edge_size)
model.predict(example_x_train) 
#array([[0.40588772]], dtype=float32)
# array([[0.38362142]], dtype=float32)
# array([[0.49879223]], dtype=float32)
# array([[0.32653403]], dtype=float32)
# Out:
# array([[0.577564]], dtype=float32)

# %%
example_x_train = X_train[5]
example_x_train = example_x_train.reshape(1, 2*edge_size)
model.predict(example_x_train) 
#array([[0.66257244]], dtype=float32)
#array([[0.72944134]], dtype=float32)
#array([[0.4988544]], dtype=float32)
#array([[0.63189554]], dtype=float32)
# Out:
# array([[0.65979993]], dtype=float32)

# %%
#Forschungsfragen
#› Lässt sich ein „hörbarer“ Musikstream erzeugen?
#› Reicht das stochastische Sampling? Wie lange ist eine optimale Sampledauer?
#› Wie ähnlich müssen sich die Urspungstracks bezüglich Stimmung, Genre, etc sein?
#› Müssen Metadaten wie Lautstärke, Tempo, Spektrum, etc mit einbezogen werden?
