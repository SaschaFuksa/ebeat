# %%
import librosa
import numpy as np
#import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from pydub import AudioSegment
from scipy import signal
from sklearn import preprocessing

# %%
pathAudio = '/home/stud/m/mh361/share/sample-same/'
files = librosa.util.find_files(pathAudio, ext=['mp3'])

song_lounge_it = []
song_tuesday_night = []
song_kingtop = []
for file in files:
    if 'Maarten Schellekens - Lounge It' in file:
        song_lounge_it.append(file)
    if 'Maarten Schellekens - Tuesday Night Radio Edit' in file:
        song_tuesday_night.append(file)
    if 'Holizna' in file:
        song_kingtop.append(file)
song_lounge_it = sorted(song_lounge_it, key=lambda x: int(x.split('_')[-1].split('.')[0]))
song_tuesday_night = sorted(song_tuesday_night, key=lambda x: int(x.split('_')[-1].split('.')[0]))
song_kingtop = sorted(song_kingtop, key=lambda x: int(x.split('_')[-1].split('.')[0]))

# %%
'Maarten Schellekens - Tuesday Night Radio Edit_43'
long_sample = song_tuesday_night[42]

# %%
# Check large sample
from matplotlib import pyplot as plt


def normalize_sample(sample):
    array_of_samples = sample.get_array_of_samples()
    np_arr = np.array(array_of_samples)
    np_arr = np_arr.reshape(1, -1)
    return preprocessing.normalize(np_arr)

sample = AudioSegment.from_mp3(long_sample)
mono_samples = sample.split_to_mono()
normalized_sample = normalize_sample(mono_samples[0])[0]

print(len(normalized_sample))
plt.plot(normalized_sample)
plt.show()

resampled_sample = signal.resample(normalized_sample, 1000)

plt.plot(resampled_sample)
plt.show()
# Out:
# 132300

# %%
print(len(song_lounge_it))
print(len(song_tuesday_night))
print(len(song_kingtop))
# Out:
# 100
# 94
# 74

# %%
full_songs = []
full_songs.extend(song_lounge_it)
full_songs.extend(song_tuesday_night)
full_songs.extend(song_kingtop)
len(full_songs)
# Out:
# 268

# %%
# todo: Check smallest sample!!
samples = []
samples_sec_canal = []
for file_name in full_songs:
    sample = AudioSegment.from_mp3(file_name)
    mono_samples = sample.split_to_mono()
    normalized_sample = normalize_sample(mono_samples[0])[0]
    #resampled_sample = signal.resample(normalized_sample, 1000)
    samples.append(normalized_sample)
    normalized_sample_sec_canal = normalize_sample(mono_samples[1])[0]
    #resampled_sample_sec_canal = signal.resample(normalized_sample_sec_canal, 1000)
    samples_sec_canal.append(normalized_sample_sec_canal)

# %%
min(map(len, samples))
# Out:
# 50097

# %%
import itertools

plt.plot(list(itertools.chain.from_iterable(samples)))
plt.show()

# %%
len(samples)
# Out:
# 268

# %%
# todo: Check smallest sample!!
samples = []
samples_sec_canal = []
for file_name in full_songs:
    sample = AudioSegment.from_mp3(file_name)
    mono_samples = sample.split_to_mono()
    normalized_sample = normalize_sample(mono_samples[0])[0]
    resampled_sample = signal.resample(normalized_sample, int(len(normalized_sample)/50))
    samples.append(resampled_sample)
    normalized_sample_sec_canal = normalize_sample(mono_samples[1])[0]
    resampled_sample_sec_canal = signal.resample(normalized_sample_sec_canal, int(len(normalized_sample)/50))
    samples_sec_canal.append(resampled_sample_sec_canal)

# %%
edge_size = min(map(len, samples))

# %%
plt.plot(list(itertools.chain.from_iterable(samples)))
plt.show()

# %%
X_train = []
Y_train = []
for i in range(len(samples)-1):
    Y_train.append(True)
    first_half = list(samples[i][-edge_size:])
    last_half = list(samples[i + 1][:edge_size])
    X_train.append(first_half+last_half)
    if(i < len(samples)-2):
        Y_train.append(True)
        sec_last_half = list(samples[i + 2][:edge_size])
        X_train.append(first_half+sec_last_half)

# %%
min(map(len, X_train))
# Out:
# 2002

# %%
len(X_train)
# Out:
# 533

# %%
plt.plot(X_train[1])
plt.show()

# %%
from numpy import random

def get_strange_end_part(samples, current_index, max_len):
    x = random.randint(max_len-1)
    if (x != current_index+1) and (x != current_index+2):
        return list(samples[x][:edge_size])
    else:
        return get_strange_end_part(samples, current_index, max_len)


for i in range(len(samples)-1):
    first_half = list(samples[i][-edge_size:])
    last_half = get_strange_end_part(samples, i, len(samples))
    X_train.append(first_half+last_half)
    Y_train.append(False)
    sec_last_half = get_strange_end_part(samples, i, len(samples))
    X_train.append(first_half+sec_last_half)
    Y_train.append(False)

# %%
len(X_train)
# Out:
# 1067

# %%
min(map(len, X_train))
# Out:
# 2002

# %%
X_train = np.array(X_train)
X_train = X_train.reshape(-1, 2*edge_size)
X_train.shape
# Out:
# (1067, 2002)

# %%
Y_train = np.array(Y_train)
Y_train = Y_train.reshape(-1, 1)
Y_train.shape
# Out:
# (1067, 1)

# %%
from keras.layers import Conv1D, LSTM, Flatten, CuDNNLSTM
from tensorflow.keras.optimizers import SGD

model = Sequential()
model.add(Conv1D(filters=512, kernel_size=2, input_shape=(2*edge_size, 1))) # 2 # 3 / filters 512
model.add(CuDNNLSTM(512, return_sequences=True)) # 256 # 8 #512 #256
model.add(Dense(512))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy']) #1 'rmsprop' 2 'adam' 3 SGD(learning_rate=0.01)
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 2001, 512)         1536
#
#  cu_dnnlstm_4 (CuDNNLSTM)    (None, 2001, 512)         2101248
#
#  dense_8 (Dense)             (None, 2001, 512)         262656
#
#  flatten_4 (Flatten)         (None, 1024512)           0
#
#  dense_9 (Dense)             (None, 1)                 1024513
#
# =================================================================
# Total params: 3,389,953
# Trainable params: 3,389,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, epochs=100, batch_size=32) 
# batch size 8
#3s 21ms/step - loss: 0.6818 - accuracy: 0.5719
# 3s 21ms/step - loss: 0.7044 - accuracy: 0.5729
# 3s 21ms/step - loss: 0.6933 - accuracy: 0.4747
# 2s 17ms/step - loss: 0.6923 - accuracy: 0.5574
# 3s 29ms/step - loss: 0.6837 - accuracy: 0.5667
#121/121 [==============================] - 4s 30ms/step - loss: 0.6872 - accuracy: 0.5595 filters 512 , lstm 512

#batch size 64
# 2s 117ms/step - loss: 0.6428 - accuracy: 0.5957
#16/16 [==============================] - 2s 114ms/step - loss: 0.6905 - accuracy: 0.5522 -> kernel 4 lstm 512
# 16/16 [==============================] - 2s 115ms/step - loss: 0.6914 - accuracy: 0.5429 kernel 3 lstm 512
# 16/16 [==============================] - 2s 134ms/step - loss: 0.6446 - accuracy: 0.6070 kernel 2 lstm 512 filters 512
# Epoch 1000/1000
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5504 - accuracy: 0.6856

#batch size 32
#  1s 46ms/step - loss: 0.7023 - accuracy: 0.5553

#batch size 128
#1s 92ms/step - loss: 0.6887 - accuracy: 0.5346
# Out:
# Epoch 1/100
# 34/34 [==============================] - 10s 237ms/step - loss: 3.9571 - accuracy: 0.4986
# Epoch 2/100
# 34/34 [==============================] - 7s 195ms/step - loss: 2.1666 - accuracy: 0.4799
# Epoch 3/100
# 34/34 [==============================] - 7s 196ms/step - loss: 0.7076 - accuracy: 0.5136
# Epoch 4/100
# 34/34 [==============================] - 7s 197ms/step - loss: 1.9535 - accuracy: 0.4864
# Epoch 5/100
# 34/34 [==============================] - 7s 199ms/step - loss: 1.7510 - accuracy: 0.5136
# Epoch 6/100
# 34/34 [==============================] - 7s 202ms/step - loss: 0.7014 - accuracy: 0.4742
# Epoch 7/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.7184 - accuracy: 0.5117
# Epoch 8/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.7255 - accuracy: 0.5080
# Epoch 9/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.8606 - accuracy: 0.4902
# Epoch 10/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.9207 - accuracy: 0.4958
# Epoch 11/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.7620 - accuracy: 0.5136
# Epoch 12/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.8086 - accuracy: 0.5108
# Epoch 13/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6986 - accuracy: 0.5230
# Epoch 14/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.7202 - accuracy: 0.5108
# Epoch 15/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.6624 - accuracy: 0.4939
# Epoch 16/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6958 - accuracy: 0.5258
# Epoch 17/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.8471 - accuracy: 0.5305
# Epoch 18/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.8320 - accuracy: 0.5239
# Epoch 19/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.3064 - accuracy: 0.5080
# Epoch 20/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.7280 - accuracy: 0.5061
# Epoch 21/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6995 - accuracy: 0.5052
# Epoch 22/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.6510 - accuracy: 0.5164
# Epoch 23/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.6983 - accuracy: 0.5248
# Epoch 24/100
# 34/34 [==============================] - 7s 204ms/step - loss: 1.5522 - accuracy: 0.5276
# Epoch 25/100
# 34/34 [==============================] - 7s 209ms/step - loss: 0.9734 - accuracy: 0.5070
# Epoch 26/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.4426 - accuracy: 0.4920
# Epoch 27/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6920 - accuracy: 0.5286
# Epoch 28/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.5671 - accuracy: 0.5192
# Epoch 29/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.4984 - accuracy: 0.5155
# Epoch 30/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.6958 - accuracy: 0.5314
# Epoch 31/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.3750 - accuracy: 0.5276
# Epoch 32/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6950 - accuracy: 0.5145
# Epoch 33/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.6654 - accuracy: 0.5127
# Epoch 34/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.4971 - accuracy: 0.5530
# Epoch 35/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.6969 - accuracy: 0.5370
# Epoch 36/100
# 34/34 [==============================] - 7s 205ms/step - loss: 2.0389 - accuracy: 0.5305
# Epoch 37/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6987 - accuracy: 0.5070
# Epoch 38/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.5381 - accuracy: 0.5183
# Epoch 39/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6915 - accuracy: 0.5370
# Epoch 40/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.3420 - accuracy: 0.5136
# Epoch 41/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.3749 - accuracy: 0.5530
# Epoch 42/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6882 - accuracy: 0.5623
# Epoch 43/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.2243 - accuracy: 0.5473
# Epoch 44/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.1505 - accuracy: 0.5380
# Epoch 45/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.6865 - accuracy: 0.5670
# Epoch 46/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.4452 - accuracy: 0.5230
# Epoch 47/100
# 34/34 [==============================] - 7s 203ms/step - loss: 0.6902 - accuracy: 0.5417
# Epoch 48/100
# 34/34 [==============================] - 7s 204ms/step - loss: 1.5540 - accuracy: 0.5164
# Epoch 49/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.3366 - accuracy: 0.5108
# Epoch 50/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.6921 - accuracy: 0.5314
# Epoch 51/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.4885 - accuracy: 0.5323
# Epoch 52/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.7348 - accuracy: 0.5342
# Epoch 53/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.2348 - accuracy: 0.5183
# Epoch 54/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.3163 - accuracy: 0.5351
# Epoch 55/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.6907 - accuracy: 0.5436
# Epoch 56/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.1139 - accuracy: 0.5220
# Epoch 57/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.2495 - accuracy: 0.5351
# Epoch 58/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6876 - accuracy: 0.5501
# Epoch 59/100
# 34/34 [==============================] - 7s 204ms/step - loss: 1.1891 - accuracy: 0.5220
# Epoch 60/100
# 34/34 [==============================] - 7s 208ms/step - loss: 0.6852 - accuracy: 0.5595
# Epoch 61/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.3149 - accuracy: 0.5314
# Epoch 62/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.9104 - accuracy: 0.5539
# Epoch 63/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6848 - accuracy: 0.5567
# Epoch 64/100
# 34/34 [==============================] - 7s 209ms/step - loss: 1.2239 - accuracy: 0.5230
# Epoch 65/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.9975 - accuracy: 0.5370
# Epoch 66/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.7692 - accuracy: 0.5464
# Epoch 67/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.3124 - accuracy: 0.5370
# Epoch 68/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6862 - accuracy: 0.5792
# Epoch 69/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.9233 - accuracy: 0.5445
# Epoch 70/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.1048 - accuracy: 0.5473
# Epoch 71/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.6803 - accuracy: 0.5623
# Epoch 72/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.2292 - accuracy: 0.5426
# Epoch 73/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.7882 - accuracy: 0.5661
# Epoch 74/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.7433 - accuracy: 0.5558
# Epoch 75/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.9686 - accuracy: 0.5417
# Epoch 76/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.2511 - accuracy: 0.5342
# Epoch 77/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6801 - accuracy: 0.5754
# Epoch 78/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.0335 - accuracy: 0.5501
# Epoch 79/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.9241 - accuracy: 0.5604
# Epoch 80/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.8405 - accuracy: 0.5670
# Epoch 81/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.1244 - accuracy: 0.5567
# Epoch 82/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6797 - accuracy: 0.5867
# Epoch 83/100
# 34/34 [==============================] - 7s 208ms/step - loss: 1.1432 - accuracy: 0.5267
# Epoch 84/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.8428 - accuracy: 0.5323
# Epoch 85/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.6788 - accuracy: 0.5961
# Epoch 86/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.3096 - accuracy: 0.5276
# Epoch 87/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.8868 - accuracy: 0.5520
# Epoch 88/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.7412 - accuracy: 0.5679
# Epoch 89/100
# 34/34 [==============================] - 7s 208ms/step - loss: 1.0367 - accuracy: 0.5595
# Epoch 90/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.8343 - accuracy: 0.5595
# Epoch 91/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.8205 - accuracy: 0.5745
# Epoch 92/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.0908 - accuracy: 0.5483
# Epoch 93/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.6761 - accuracy: 0.5726
# Epoch 94/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.8763 - accuracy: 0.5567
# Epoch 95/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.8109 - accuracy: 0.5961
# Epoch 96/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.7338 - accuracy: 0.5558
# Epoch 97/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.1177 - accuracy: 0.5586
# Epoch 98/100
# 34/34 [==============================] - 7s 205ms/step - loss: 1.0259 - accuracy: 0.5539
# Epoch 99/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.6704 - accuracy: 0.5867
# Epoch 100/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.9271 - accuracy: 0.5717

# %%
example_x_train = X_train[-2]
example_x_train = example_x_train.reshape(1, 2*edge_size)
model.predict(example_x_train) 
#array([[0.40588772]], dtype=float32)
# array([[0.38362142]], dtype=float32)
# array([[0.49879223]], dtype=float32)
# array([[0.32653403]], dtype=float32)
# Out:
# array([[0.38437712]], dtype=float32)

# %%
example_x_train = X_train[1]
example_x_train = example_x_train.reshape(1, 2*edge_size)
model.predict(example_x_train) 
#array([[0.66257244]], dtype=float32)
#array([[0.72944134]], dtype=float32)
#array([[0.4988544]], dtype=float32)
#array([[0.63189554]], dtype=float32)
# Out:
# array([[0.763327]], dtype=float32)

# %%
#Forschungsfragen
#› Lässt sich ein „hörbarer“ Musikstream erzeugen?
#› Reicht das stochastische Sampling? Wie lange ist eine optimale Sampledauer?
#› Wie ähnlich müssen sich die Urspungstracks bezüglich Stimmung, Genre, etc sein?
#› Müssen Metadaten wie Lautstärke, Tempo, Spektrum, etc mit einbezogen werden?
