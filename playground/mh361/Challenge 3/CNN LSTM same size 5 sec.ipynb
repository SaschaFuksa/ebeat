# %%
import librosa
import numpy as np
#import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from pydub import AudioSegment
from scipy import signal
from sklearn import preprocessing

# %%
pathAudio = '/home/stud/m/mh361/share/samples5sec/'
files = librosa.util.find_files(pathAudio, ext=['mp3'])

song_lounge_it = []
song_tuesday_night = []
song_kingtop = []
for file in files:
    if 'Maarten Schellekens - Lounge It' in file:
        song_lounge_it.append(file)
    if 'Maarten Schellekens - Tuesday Night Radio Edit' in file:
        song_tuesday_night.append(file)
    if 'Holizna' in file:
        song_kingtop.append(file)
song_lounge_it = sorted(song_lounge_it, key=lambda x: int(x.split('_')[-1].split('.')[0]))
song_tuesday_night = sorted(song_tuesday_night, key=lambda x: int(x.split('_')[-1].split('.')[0]))
song_kingtop = sorted(song_kingtop, key=lambda x: int(x.split('_')[-1].split('.')[0]))

# %%
'Maarten Schellekens - Tuesday Night Radio Edit_43'
long_sample = song_tuesday_night[42]

# %%
# Check large sample
from matplotlib import pyplot as plt


def normalize_sample(sample):
    array_of_samples = sample.get_array_of_samples()
    np_arr = np.array(array_of_samples)
    np_arr = np_arr.reshape(1, -1)
    return preprocessing.normalize(np_arr)

sample = AudioSegment.from_mp3(long_sample)
mono_samples = sample.split_to_mono()
normalized_sample = normalize_sample(mono_samples[0])[0]

print(len(normalized_sample))
plt.plot(normalized_sample)
plt.show()

resampled_sample = signal.resample(normalized_sample, 1000)

plt.plot(resampled_sample)
plt.show()
# Out:
# 220500

# %%
print(len(song_lounge_it))
print(len(song_tuesday_night))
print(len(song_kingtop))
# Out:
# 60
# 57
# 45

# %%
full_songs = []
full_songs.extend(song_lounge_it)
full_songs.extend(song_tuesday_night)
full_songs.extend(song_kingtop)
len(full_songs)
# Out:
# 162

# %%
# todo: Check smallest sample!!
samples = []
samples_sec_canal = []
for file_name in full_songs:
    sample = AudioSegment.from_mp3(file_name)
    mono_samples = sample.split_to_mono()
    normalized_sample = normalize_sample(mono_samples[0])[0]
    #resampled_sample = signal.resample(normalized_sample, 1000)
    samples.append(normalized_sample)
    normalized_sample_sec_canal = normalize_sample(mono_samples[1])[0]
    #resampled_sample_sec_canal = signal.resample(normalized_sample_sec_canal, 1000)
    samples_sec_canal.append(normalized_sample_sec_canal)

# %%
min(map(len, samples))
# Out:
# 85554

# %%
import itertools

plt.plot(list(itertools.chain.from_iterable(samples)))
plt.show()

# %%
len(samples)
# Out:
# 162

# %%
# todo: Check smallest sample!!
samples = []
samples_sec_canal = []
for file_name in full_songs:
    sample = AudioSegment.from_mp3(file_name)
    mono_samples = sample.split_to_mono()
    normalized_sample = normalize_sample(mono_samples[0])[0]
    resampled_sample = signal.resample(normalized_sample, int(len(normalized_sample)/50))
    samples.append(resampled_sample)
    normalized_sample_sec_canal = normalize_sample(mono_samples[1])[0]
    resampled_sample_sec_canal = signal.resample(normalized_sample_sec_canal, int(len(normalized_sample)/50))
    samples_sec_canal.append(resampled_sample_sec_canal)

# %%
edge_size = min(map(len, samples))

# %%
plt.plot(list(itertools.chain.from_iterable(samples)))
plt.show()

# %%
X_train = []
Y_train = []
for i in range(len(samples)-1):
    Y_train.append(True)
    first_half = list(samples[i][-edge_size:])
    last_half = list(samples[i + 1][:edge_size])
    X_train.append(first_half+last_half)
    if(i < len(samples)-2):
        Y_train.append(True)
        sec_last_half = list(samples[i + 2][:edge_size])
        X_train.append(first_half+sec_last_half)

# %%
min(map(len, X_train))
# Out:
# 3422

# %%
len(X_train)
# Out:
# 321

# %%
plt.plot(X_train[1])
plt.show()

# %%
from numpy import random

def get_strange_end_part(samples, current_index, max_len):
    x = random.randint(max_len-1)
    if (x != current_index+1) and (x != current_index+2):
        return list(samples[x][:edge_size])
    else:
        return get_strange_end_part(samples, current_index, max_len)


for i in range(len(samples)-1):
    first_half = list(samples[i][-edge_size:])
    last_half = get_strange_end_part(samples, i, len(samples))
    X_train.append(first_half+last_half)
    Y_train.append(False)
    sec_last_half = get_strange_end_part(samples, i, len(samples))
    X_train.append(first_half+sec_last_half)
    Y_train.append(False)

# %%
len(X_train)
# Out:
# 643

# %%
min(map(len, X_train))
# Out:
# 3422

# %%
X_train = np.array(X_train)
X_train = X_train.reshape(-1, 2*edge_size)
X_train.shape
# Out:
# (643, 3422)

# %%
Y_train = np.array(Y_train)
Y_train = Y_train.reshape(-1, 1)
Y_train.shape
# Out:
# (643, 1)

# %%
from keras.layers import Conv1D, LSTM, Flatten, CuDNNLSTM
from tensorflow.keras.optimizers import SGD

model = Sequential()
model.add(Conv1D(filters=512, kernel_size=2, input_shape=(2*edge_size, 1))) # 2 # 3 / filters 512
model.add(CuDNNLSTM(512, return_sequences=True)) # 256 # 8 #512 #256
model.add(Dense(512))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy']) #1 'rmsprop' 2 'adam' 3 SGD(learning_rate=0.01)
model.summary()
# Out:
# 2022-06-24 11:48:35.194160: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-24 11:48:42.740252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11417 MB memory:  -> device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 3421, 512)         1536
#
#  cu_dnnlstm (CuDNNLSTM)      (None, 3421, 512)         2101248
#
#  dense (Dense)               (None, 3421, 512)         262656
#
#  flatten (Flatten)           (None, 1751552)           0
#
#  dense_1 (Dense)             (None, 1)                 1751553
#
# =================================================================
# Total params: 4,116,993
# Trainable params: 4,116,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, epochs=100, batch_size=32) 
# batch size 8
#3s 21ms/step - loss: 0.6818 - accuracy: 0.5719
# 3s 21ms/step - loss: 0.7044 - accuracy: 0.5729
# 3s 21ms/step - loss: 0.6933 - accuracy: 0.4747
# 2s 17ms/step - loss: 0.6923 - accuracy: 0.5574
# 3s 29ms/step - loss: 0.6837 - accuracy: 0.5667
#121/121 [==============================] - 4s 30ms/step - loss: 0.6872 - accuracy: 0.5595 filters 512 , lstm 512

#batch size 64
# 2s 117ms/step - loss: 0.6428 - accuracy: 0.5957
#16/16 [==============================] - 2s 114ms/step - loss: 0.6905 - accuracy: 0.5522 -> kernel 4 lstm 512
# 16/16 [==============================] - 2s 115ms/step - loss: 0.6914 - accuracy: 0.5429 kernel 3 lstm 512
# 16/16 [==============================] - 2s 134ms/step - loss: 0.6446 - accuracy: 0.6070 kernel 2 lstm 512 filters 512
# Epoch 1000/1000
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5504 - accuracy: 0.6856

#batch size 32
#  1s 46ms/step - loss: 0.7023 - accuracy: 0.5553

#batch size 128
#1s 92ms/step - loss: 0.6887 - accuracy: 0.5346
# Out:
# Epoch 1/100
# 2022-06-24 11:48:54.316005: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 7605
# 2022-06-24 11:48:54.324509: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-24 11:48:54.325456: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-24 11:48:54.325491: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-06-24 11:48:54.326011: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-24 11:48:54.326068: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 21/21 [==============================] - 32s 646ms/step - loss: 13.0440 - accuracy: 0.5008
# Epoch 2/100
# 21/21 [==============================] - 8s 389ms/step - loss: 1.1327 - accuracy: 0.5334
# Epoch 3/100
# 21/21 [==============================] - 8s 392ms/step - loss: 0.7574 - accuracy: 0.5148
# Epoch 4/100
# 21/21 [==============================] - 8s 390ms/step - loss: 4.1932 - accuracy: 0.4977
# Epoch 5/100
# 21/21 [==============================] - 8s 393ms/step - loss: 0.7036 - accuracy: 0.4806
# Epoch 6/100
# 21/21 [==============================] - 8s 393ms/step - loss: 5.0804 - accuracy: 0.4977
# Epoch 7/100
# 21/21 [==============================] - 8s 393ms/step - loss: 0.7174 - accuracy: 0.5039
# Epoch 8/100
# 21/21 [==============================] - 8s 396ms/step - loss: 1.0565 - accuracy: 0.5288
# Epoch 9/100
# 21/21 [==============================] - 8s 395ms/step - loss: 3.6345 - accuracy: 0.5474
# Epoch 10/100
# 21/21 [==============================] - 8s 397ms/step - loss: 0.7105 - accuracy: 0.4728
# Epoch 11/100
# 21/21 [==============================] - 8s 398ms/step - loss: 4.6007 - accuracy: 0.5101
# Epoch 12/100
# 21/21 [==============================] - 8s 404ms/step - loss: 0.7592 - accuracy: 0.5039
# Epoch 13/100
# 21/21 [==============================] - 8s 398ms/step - loss: 0.6995 - accuracy: 0.5194
# Epoch 14/100
# 21/21 [==============================] - 8s 403ms/step - loss: 5.1119 - accuracy: 0.4883
# Epoch 15/100
# 21/21 [==============================] - 9s 409ms/step - loss: 0.7129 - accuracy: 0.4930
# Epoch 16/100
# 21/21 [==============================] - 9s 407ms/step - loss: 0.7058 - accuracy: 0.5117
# Epoch 17/100
# 21/21 [==============================] - 9s 408ms/step - loss: 4.0629 - accuracy: 0.5303
# Epoch 18/100
# 21/21 [==============================] - 9s 407ms/step - loss: 0.7103 - accuracy: 0.5148
# Epoch 19/100
# 21/21 [==============================] - 8s 397ms/step - loss: 4.2322 - accuracy: 0.5272
# Epoch 20/100
# 21/21 [==============================] - 9s 413ms/step - loss: 0.7151 - accuracy: 0.5117
# Epoch 21/100
# 21/21 [==============================] - 9s 415ms/step - loss: 0.6976 - accuracy: 0.5257
# Epoch 22/100
# 21/21 [==============================] - 9s 409ms/step - loss: 5.0879 - accuracy: 0.4961
# Epoch 23/100
# 21/21 [==============================] - 9s 409ms/step - loss: 0.7498 - accuracy: 0.5101
# Epoch 24/100
# 21/21 [==============================] - 9s 413ms/step - loss: 0.6955 - accuracy: 0.5148
# Epoch 25/100
# 21/21 [==============================] - 9s 417ms/step - loss: 4.0835 - accuracy: 0.5257
# Epoch 26/100
# 21/21 [==============================] - 9s 415ms/step - loss: 0.7309 - accuracy: 0.5443
# Epoch 27/100
# 21/21 [==============================] - 9s 408ms/step - loss: 2.7325 - accuracy: 0.5070
# Epoch 28/100
# 21/21 [==============================] - 8s 402ms/step - loss: 0.6902 - accuracy: 0.5163
# Epoch 29/100
# 21/21 [==============================] - 9s 417ms/step - loss: 4.0914 - accuracy: 0.4992
# Epoch 30/100
# 21/21 [==============================] - 9s 426ms/step - loss: 0.9791 - accuracy: 0.5288
# Epoch 31/100
# 21/21 [==============================] - 9s 426ms/step - loss: 0.6986 - accuracy: 0.5443
# Epoch 32/100
# 21/21 [==============================] - 9s 416ms/step - loss: 0.6842 - accuracy: 0.5505
# Epoch 33/100
# 21/21 [==============================] - 9s 411ms/step - loss: 2.9249 - accuracy: 0.5319
# Epoch 34/100
# 21/21 [==============================] - 9s 405ms/step - loss: 0.6841 - accuracy: 0.5505
# Epoch 35/100
# 21/21 [==============================] - 9s 407ms/step - loss: 5.8010 - accuracy: 0.4992
# Epoch 36/100
# 21/21 [==============================] - 9s 420ms/step - loss: 0.7049 - accuracy: 0.5552
# Epoch 37/100
# 21/21 [==============================] - 9s 417ms/step - loss: 0.6880 - accuracy: 0.5334
# Epoch 38/100
# 21/21 [==============================] - 9s 422ms/step - loss: 3.1873 - accuracy: 0.5132
# Epoch 39/100
# 21/21 [==============================] - 9s 415ms/step - loss: 0.6925 - accuracy: 0.5537
# Epoch 40/100
# 21/21 [==============================] - 9s 426ms/step - loss: 3.8762 - accuracy: 0.5365
# Epoch 41/100
# 21/21 [==============================] - 9s 418ms/step - loss: 0.7007 - accuracy: 0.5365
# Epoch 42/100
# 21/21 [==============================] - 9s 406ms/step - loss: 0.6871 - accuracy: 0.5723
# Epoch 43/100
# 21/21 [==============================] - 9s 414ms/step - loss: 2.8309 - accuracy: 0.4992
# Epoch 44/100
# 21/21 [==============================] - 9s 409ms/step - loss: 0.6833 - accuracy: 0.5428
# Epoch 45/100
# 21/21 [==============================] - 9s 413ms/step - loss: 0.7022 - accuracy: 0.5443
# Epoch 46/100
# 21/21 [==============================] - 9s 414ms/step - loss: 4.3442 - accuracy: 0.5241
# Epoch 47/100
# 21/21 [==============================] - 9s 415ms/step - loss: 0.6775 - accuracy: 0.5645
# Epoch 48/100
# 21/21 [==============================] - 9s 411ms/step - loss: 0.7357 - accuracy: 0.5816
# Epoch 49/100
# 21/21 [==============================] - 9s 421ms/step - loss: 2.8523 - accuracy: 0.5226
# Epoch 50/100
# 21/21 [==============================] - 9s 409ms/step - loss: 0.6842 - accuracy: 0.5365
# Epoch 51/100
# 21/21 [==============================] - 9s 410ms/step - loss: 1.1053 - accuracy: 0.5739
# Epoch 52/100
# 21/21 [==============================] - 9s 420ms/step - loss: 1.4089 - accuracy: 0.5754
# Epoch 53/100
# 21/21 [==============================] - 9s 413ms/step - loss: 0.6823 - accuracy: 0.5661
# Epoch 54/100
# 21/21 [==============================] - 9s 412ms/step - loss: 5.0476 - accuracy: 0.5365
# Epoch 55/100
# 21/21 [==============================] - 9s 421ms/step - loss: 0.7210 - accuracy: 0.5365
# Epoch 56/100
# 21/21 [==============================] - 8s 397ms/step - loss: 0.6854 - accuracy: 0.5661
# Epoch 57/100
# 21/21 [==============================] - 9s 406ms/step - loss: 3.6961 - accuracy: 0.4977
# Epoch 58/100
# 21/21 [==============================] - 9s 422ms/step - loss: 0.6791 - accuracy: 0.5723
# Epoch 59/100
# 21/21 [==============================] - 9s 407ms/step - loss: 2.4566 - accuracy: 0.5661
# Epoch 60/100
# 21/21 [==============================] - 9s 426ms/step - loss: 0.7876 - accuracy: 0.5723
# Epoch 61/100
# 21/21 [==============================] - 9s 411ms/step - loss: 0.6774 - accuracy: 0.5754
# Epoch 62/100
# 21/21 [==============================] - 9s 422ms/step - loss: 3.2879 - accuracy: 0.5226
# Epoch 63/100
# 21/21 [==============================] - 8s 397ms/step - loss: 0.6863 - accuracy: 0.5645
# Epoch 64/100
# 21/21 [==============================] - 9s 418ms/step - loss: 3.0146 - accuracy: 0.5505
# Epoch 65/100
# 21/21 [==============================] - 9s 414ms/step - loss: 0.7314 - accuracy: 0.5583
# Epoch 66/100
# 21/21 [==============================] - 9s 423ms/step - loss: 0.8596 - accuracy: 0.5459
# Epoch 67/100
# 21/21 [==============================] - 9s 407ms/step - loss: 2.3069 - accuracy: 0.5521
# Epoch 68/100
# 21/21 [==============================] - 9s 411ms/step - loss: 0.6701 - accuracy: 0.5941
# Epoch 69/100
# 21/21 [==============================] - 9s 413ms/step - loss: 2.7042 - accuracy: 0.5770
# Epoch 70/100
# 21/21 [==============================] - 9s 420ms/step - loss: 0.7052 - accuracy: 0.5770
# Epoch 71/100
# 21/21 [==============================] - 9s 419ms/step - loss: 0.6772 - accuracy: 0.5708
# Epoch 72/100
# 21/21 [==============================] - 9s 412ms/step - loss: 2.7822 - accuracy: 0.5537
# Epoch 73/100
# 21/21 [==============================] - 9s 407ms/step - loss: 0.6648 - accuracy: 0.5956
# Epoch 74/100
# 21/21 [==============================] - 9s 412ms/step - loss: 0.6701 - accuracy: 0.5801
# Epoch 75/100
# 21/21 [==============================] - 9s 421ms/step - loss: 2.8645 - accuracy: 0.5692
# Epoch 76/100
# 21/21 [==============================] - 9s 420ms/step - loss: 0.6721 - accuracy: 0.5956
# Epoch 77/100
# 21/21 [==============================] - 9s 410ms/step - loss: 0.6711 - accuracy: 0.5925
# Epoch 78/100
# 21/21 [==============================] - 9s 410ms/step - loss: 2.9903 - accuracy: 0.5319
# Epoch 79/100
# 21/21 [==============================] - 9s 414ms/step - loss: 0.6665 - accuracy: 0.5879
# Epoch 80/100
# 21/21 [==============================] - 9s 413ms/step - loss: 2.6670 - accuracy: 0.5645
# Epoch 81/100
# 21/21 [==============================] - 9s 418ms/step - loss: 0.6858 - accuracy: 0.5645
# Epoch 82/100
# 21/21 [==============================] - 9s 423ms/step - loss: 0.6684 - accuracy: 0.5816
# Epoch 83/100
# 21/21 [==============================] - 9s 416ms/step - loss: 2.8070 - accuracy: 0.5739
# Epoch 84/100
# 21/21 [==============================] - 9s 405ms/step - loss: 0.6693 - accuracy: 0.5894
# Epoch 85/100
# 21/21 [==============================] - 9s 419ms/step - loss: 0.7117 - accuracy: 0.5910
# Epoch 86/100
# 21/21 [==============================] - 9s 423ms/step - loss: 2.8653 - accuracy: 0.5412
# Epoch 87/100
# 21/21 [==============================] - 9s 420ms/step - loss: 0.6628 - accuracy: 0.6019
# Epoch 88/100
# 21/21 [==============================] - 9s 414ms/step - loss: 2.4663 - accuracy: 0.5692
# Epoch 89/100
# 21/21 [==============================] - 9s 409ms/step - loss: 1.0909 - accuracy: 0.5677
# Epoch 90/100
# 21/21 [==============================] - 9s 416ms/step - loss: 0.6547 - accuracy: 0.6143
# Epoch 91/100
# 21/21 [==============================] - 9s 412ms/step - loss: 2.9178 - accuracy: 0.5350
# Epoch 92/100
# 21/21 [==============================] - 9s 421ms/step - loss: 0.6681 - accuracy: 0.5925
# Epoch 93/100
# 21/21 [==============================] - 9s 409ms/step - loss: 0.6621 - accuracy: 0.5879
# Epoch 94/100
# 21/21 [==============================] - 9s 412ms/step - loss: 2.6073 - accuracy: 0.5505
# Epoch 95/100
# 21/21 [==============================] - 8s 401ms/step - loss: 0.6583 - accuracy: 0.5863
# Epoch 96/100
# 21/21 [==============================] - 9s 413ms/step - loss: 2.3469 - accuracy: 0.5505
# Epoch 97/100
# 21/21 [==============================] - 9s 422ms/step - loss: 0.6642 - accuracy: 0.6019
# Epoch 98/100
# 21/21 [==============================] - 9s 407ms/step - loss: 3.0825 - accuracy: 0.5474
# Epoch 99/100
# 21/21 [==============================] - 9s 416ms/step - loss: 0.7093 - accuracy: 0.5988
# Epoch 100/100
# 21/21 [==============================] - 9s 409ms/step - loss: 0.6577 - accuracy: 0.6065

# %%
example_x_train = X_train[-2]
example_x_train = example_x_train.reshape(1, 2*edge_size)
model.predict(example_x_train) 
#array([[0.40588772]], dtype=float32)
# array([[0.38362142]], dtype=float32)
# array([[0.49879223]], dtype=float32)
# array([[0.32653403]], dtype=float32)
# Out:
# array([[0.5030762]], dtype=float32)

# %%
example_x_train = X_train[5]
example_x_train = example_x_train.reshape(1, 2*edge_size)
model.predict(example_x_train) 
#array([[0.66257244]], dtype=float32)
#array([[0.72944134]], dtype=float32)
#array([[0.4988544]], dtype=float32)
#array([[0.63189554]], dtype=float32)
# Out:
# array([[0.7154239]], dtype=float32)

# %%
#Forschungsfragen
#› Lässt sich ein „hörbarer“ Musikstream erzeugen?
#› Reicht das stochastische Sampling? Wie lange ist eine optimale Sampledauer?
#› Wie ähnlich müssen sich die Urspungstracks bezüglich Stimmung, Genre, etc sein?
#› Müssen Metadaten wie Lautstärke, Tempo, Spektrum, etc mit einbezogen werden?
